# %% [markdown]
# <a href="https://colab.research.google.com/github/FridayxVision/ICT_DSA/blob/main/DSA_CaseStudy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bank Account

# %%
account_bal = 0

def deposit(amount):
  global account_bal
  account_bal += amount
  print(f"Deposited {amount}, Current balance is {account_bal}")
  return account_bal

def withdraw(amount):
  global account_bal
  if amount > account_bal:
    print("insufficent balance")
  else:
    account_bal -= amount
    print(f"Withdrawn:{amount}, Available balance is {account_bal}")

def check_bal():
  print(f"Account Balance : {account_bal}")

# %%
deposit(1000)
withdraw(500)
check_bal()
# Out:
# Deposited 1000, Current balance is 3500
# Withdrawn:500, Available balance is 3000
# Account Balance : 3000

# %% [markdown]
# #Weather Analyzer

# %%
region = 'kerala'
temp = 20
humidity = 50

if temp > 30:
  print('very hot')
elif 25 <= temp <= 30:
  print('hot')
elif 15 <= temp <= 24:
  print('normal')
else:
  print('cold')

total_temp = [28,29,30,31,31,33,34]

def avg_temp(total_temp):
  print(sum(total_temp) / len(total_temp))

avg_temp(total_temp)
# Out:
# normal
# 30.857142857142858

# %%
# Out:
# 30.857142857142858
